# %% [markdown]
# <img src="GeorgiaTech_Navy.png" width=200/>

# %% [markdown]
# # Optimizing a Recipe for Diet Based on an Image
# A CS7643 Project.
#
# ## Team Members
# * Peter Veikos
# * Luis Murrugarra
# * Esteban Fajardo
#
# ## App Instructions
# Upload your image and get the best recipe in terms on nutritional value and caloric intake

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
btn_upload = widgets.FileUpload(
    accept='.jpg',
    multiple=False
)

# %%
# Read pre-trained model
learn_inf = load_learner('resnet34_out_lr.pkl')

# %%
out_pl = widgets.Output()
lbl_pred = widgets.HTML()
btn_run = widgets.Button(description='Classify')

def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(512,512))
    pred, pred_idx, probs = learn_inf.predict(img)
    lbl_pred.value = f'<h2> Prediction: </h2> The image is {pred} with probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
btn_upload = widgets.FileUpload()
VBox([widgets.HTML('<h1> Select your food! </h1>'), 
      widgets.HTML('Upload your image by clicking the upload button and then press Classify!'),
      btn_upload,
      btn_run,
      widgets.HTML('<h3> Input Image: </h3>'),
      out_pl, 
      lbl_pred])
